# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import urllib.request
from IPython.display import display_html

import urllib3

# %% [markdown]
# Get list of public company in Vietnam Market

# %%
import urllib

page = urllib.request.urlopen("/path/").read()
print(page)

# %%
html = 'Danh sách doanh nghiệp niêm yết, đại chúng, công ty chứng khoán _ CafeF.vn.html'

soup =  BeautifulSoup(open(html),'html.parser')
# table = soup.find("td",{"id":"CafeF_ThiTruongNiemYet_Content"})

# %%
soup.string

# %%
table = table.find("td",{"id":"CafeF_ThiTruongNiemYet_Content"})

# %%
print(table)
# Out:
# None

# %%
pd.read_html(table)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-79e9499810fc> in <module>
# ----> 1 pd.read_html(table)
#
# ~/.local/lib/python3.6/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1103         na_values=na_values,
#    1104         keep_default_na=keep_default_na,
# -> 1105         displayed_only=displayed_only,
#    1106     )
#
# ~/.local/lib/python3.6/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     886     retained = None
#     887     for flav in flavor:
# --> 888         parser = _parser_dispatch(flav)
#     889         p = parser(io, compiled_match, attrs, encoding, displayed_only)
#     890
#
# ...
