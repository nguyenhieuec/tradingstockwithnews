# %%
import pandas as pd

# %%
raw = pd.read_csv("/home/hieu/Desktop/newfull.csv")

# %%
testbert =  raw.head(100)

# %%
testbert
# Out:
#     Unnamed: 0                                           fulltext  \
# 0            0  THÔNG TIN CÔNG TY Thứ 4, 10/07/2019, 09:34 Caf...
# 1            1  THÔNG TIN CÔNG TY Thứ 2, 01/07/2019, 14:21 Caf...
# 2            2  Tuần mới từ 3/6 đến 7/6/2019 có 40 doanh nghiệ...
# 3            3  Tập đoàn Xăng dầu Việt Nam (PLX): Ngày 31/5 – ...
# 4            4  THÔNG TIN CÔNG TY Thứ 3, 28/05/2019, 13:27 Caf...
# ..         ...                                                ...
# 95          95  (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn ...
# 96          96  (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn ...
# 97          97  Sáng ngày 15/06, CTCP Nhựa và Môi trường Xanh ...
# 98          98  (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn ...
# 99          99  (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn ...
#
#                                               keyword          newsdate  \
# 0   ['hiện', 'phó', 'thế', 'phiếu', 'dịch', '2800'...  10/07/2019 09:34
# 1   ['hiện', 'phó', 'thế', 'thực', 'dịch', '2800',...  01/07/2019 14:21
# 2   ['tức', 'doanh', 'va', 'tiền', 'phiếu', 'chi',...  03/06/2019 08:55
# 3   ['tức', 'tien', 'tiền', 'quyền', 'thời', 'nhan...  28/05/2019 13:46
# 4   ['tức', 'tien', 'tra', 'tiền', 'ký', 'hiện', '...  28/05/2019 13:27
# ..                                                ...               ...
# 95  ['đáng', 'tổng', 'tưtuy', 'aaa', 'fund', 'pyn'...  09/07/2018 16:43
# 96  ['đáng', 'tổng', 'tưtuy', 'aaa', 'trị', 'tinh'...  06/07/2018 16:12
# 97  ['đồng', 'phát', 'aaa', 'thay', 'usd', 'nghiệp...  19/06/2018 09:45
# 98  ['đáng', 'ctcp', 'tổng', 'tưtuy', 'thực', 'dữ'...  18/06/2018 15:15
# 99  ['83599988', 'đáng', 'yet', 'tổng', 'aaa', 'tư...  07/06/2018 10:42
#
#                                              summnary
# 0   THÔNG TIN CÔNG TY Thứ 4, 10/07/2019, 09:34 Caf...
# 1   THÔNG TIN CÔNG TY Thứ 2, 01/07/2019, 14:21 Caf...
# 2   Tuần mới từ 3/6 đến 7/6/2019 có 40 doanh nghiệ...
# 3   Thời gian thanh toán 23/7/2019.\nThời gian tha...
# 4   THÔNG TIN CÔNG TY Thứ 3, 28/05/2019, 13:27 Caf...
# ..                                                ...
# 95  (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn ...
# 96  (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn ...
# 97  Sáng ngày 15/06, CTCP Nhựa và Môi trường Xanh ...
# 98  (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn ...
# 99  (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn ...
#
# [100 rows x 5 columns]

# %%
 for row in testbert.itertuples():
        print(row.Index, row.fulltext)
# Out:
# 0 THÔNG TIN CÔNG TY Thứ 4, 10/07/2019, 09:34 CafeF.vn > Dữ liệu A32 Công ty cổ phần 32 (UpCOM) Giá hiện tại: A32 23.5 0(0) Hồ sơ công ty GDCĐ lớn & CĐ nội bộ Hồ sơ ceo
#
# Đơn vị KL: 10,000 CP Đơn vị giá: 1,000 VND
#
# Biểu đồ GTGD và KLGD trong 1 tháng Thông tin tài chính A32: Ông Nguyễn Thế Anh - Phó Chủ tịch HĐQT đã mua 2.800 CP Nguyễn Thế Anh - Phó Chủ tịch HĐQT, Tổng Giám đốc - đã mua 2.800 CP - Tên cá nhân thực hiện giao dịch: Nguyễn Thế Anh
#
# - Chức vụ hiện nay tại TCNY: Phó Chủ tịch HĐQT, Tổng Giám đốc
#
# - Mã chứng khoán: A32
#
# - Số lượng cổ phiếu nắm giữ trước khi thực hiện giao dịch: 69.900 CP (tỷ lệ 1,03%)
#
# - Số lượng cổ phiếu đăng ký mua: 2.800 CP
#
# - Số lượng cổ phiếu đã mua: 2.800 CP
#
# - Số lượng cổ phiếu nắm giữ sau khi thực hiện giao dịch: 72.700 CP (tỷ lệ 1,07%)
#
# - Ngày bắt đầu giao dịch: 04/07/2019
#
# - Ngày kết thúc giao dịch: 04/07/2019.
#
# Upcom:
# 1 THÔNG TIN CÔNG TY Thứ 2, 01/07/2019, 14:21 CafeF.vn > Dữ liệu A32 Công ty cổ phần 32 (UpCOM) Giá hiện tại: A32 23.5 0(0) Hồ sơ công ty GDCĐ lớn & CĐ nội bộ Hồ sơ ceo
#
# Đơn vị KL: 10,000 CP Đơn vị giá: 1,000 VND
#
# Biểu đồ GTGD và KLGD trong 1 tháng Thông tin tài chính A32: Ông Nguyễn Thế Anh - Phó Chủ tịch HĐQT đăng ký mua 2.800 CP Nguyễn Thế Anh - Phó Chủ tịch HĐQT, Tổng Giám đốc - đăng ký mua 2.800 CP - Tên cá nhân thực hiện giao dịch: Nguyễn Thế Anh
#
# - Chức vụ hiện nay tại TCNY: Phó Chủ tịch HĐQT, Tổng Giám đốc
#
# - Mã chứng khoán: A32
#
# - Số lượng cổ phiếu nắm giữ trước khi thực hiện giao dịch: 69.900 CP (tỷ lệ 1,03%)
#
# - Số lượng cổ phiếu đăng ký mua: 2.800 CP
#
# - Mục đích thực hiện giao dịch: Tăng tỷ lệ sở hữu
#
# - Phương thức giao dịch: Khớp lệnh
#
# - Ngày dự kiến bắt đầu giao dịch: 02/07/2019
#
# - Ngày dự kiến kết thúc giao dịch: 30/07/2019.
#
# Upcom:
# 2 Tuần mới từ 3/6 đến 7/6/2019 có 40 doanh nghiệp công bố chốt quyền nhận cổ tức bằng tiền, bằng cổ phiếu và chia cổ phiếu thưởng cho cổ đông. Trong số đó, có rất nhiều doanh nghiệp "hot" được nhiều nhà đầu tư quan tâm như Nhựa Bình Minh (BMP), như Vinamilk, như PNJ, như Viettel Post... Nhà đầu tư muốn nhận số cổ tức này cần mua cổ phiếu trước ngày lăn chốt.
#
# Ngày 3/6/2019: VCS, CSV, CSC, KHP, HHA, PTS
#
# CTCP Vicostone (VCS) chi tạm ứng cổ tức đợt 1/2019 bằng tiền tỷ lệ 20%. Thời gian thanh toán 10/6/2019.
#
# CTCP Hóa chất cơ bản Miền Nam (CSV) chi trả cổ tức đợt 3/2018 bằng tiền tỷ lệ 16%. Thời gian thanh toán 17/6/2019.
#
# CTCP Tập đoàn Cotana (CSC) chi trả cổ tức năm 2018 bằng tiền tỷ lệ 10%. Thời gian thanh toán 14/6/2019.
#
# CTCP Phân bón và hóa chất Dầu khí Miền Trung (PCE) chi trả cổ tức năm 2018 bằng tiền tỷ lệ 12%. Thời gian thanh toán 28/6/2019.
#
# CTCP Điện lực Khánh Hòa (KHP) chi trả cổ tức đợt 2/2018 bằng tiền tỷ lệ 2%. Thời gian thanh toán 21/6/2019.
#
# CTCP Văn phòng phẩm Hồng Hà (HHA) chi trả cổ tức năm 2018 bằng tiền tỷ lệ 20%. Thời gian thanh toán 20/6/2019.
#
# CTCP Vận tải và dịch vụ Petrolimex Hải Phòng (PTS) chi trả cổ tức năm 2018 bằng tiền tỷ lệ 7%. Thời gian thanh toán 12/6/2019.
#
# Ngày 4/6/2019: BMP, VTP, HAH, ARM, VTB, THI, HTC
#
# Ngày 4/6 là ngày giao dịch không hưởng quyền để CTCP Nhựa Bình Minh (mã chứng khoán BMP) chốt danh sách cổ đông thực hiện chi trả cổ tức đợt 2/2018 bằng tiền tỷ lệ 25%, tương ứng cổ đông sở hữu 1 cổ phiếu được nhận về 2.500 đồng. Thời gian thanh toán 20/6/2019.
#
# Trước đó Nhựa Bình Minh đã tạm ứng cổ tức đợt 1/2018 cũng bằng tiền tỷ lệ 15%. Tính cả lần này Nhựa Bình Minh trả cổ tức tổng tỷ lệ 40%, hoàn thành mức cổ tức dự kiến chi trả cho năm 2018.
#
# Năm 2018 Nhựa Bình Minh đạt 4.130 tỷ đồng doanh thu và gần 428 tỷ đồng lợi nhuận sau thuế. Còn năm 2019 công ty đặt mục tiêu tăng trưởng nhẹ với 4.300 tỷ đồng doanh thu và 540 tỷ đồng lợi nhuận trước thuế. Phấn đấu chia cổ tức tối thiểu tỷ lệ 20%.
#
# Ngày 4/6 là ngày giao dịch không hưởng quyền để Tổng CTCP Bưu chính Viettel (Viettel Post – mã chứng khoán VTP) chốt danh sách cổ đông phát hành gần 17,13 triệu cổ phiếu trả cổ tức năm 2018 tỷ lệ 1.000:414. Giá trị phát hành theo mệnh giá gần 171,3 tỷ đồng. Nguồn vốn phát hành lấy từ LNST chưa phân phối năm 2018.
#
# Kết quả kinh doanh, năm 2018 Viettel Post đạt 4.922 tỷ đồng doanh thu, tăng 22% so với cùng kỳ. Lợi nhuận sau thuế đạt 279 tỷ đồng, tăng trưởng 64,1% so với lợi nhuận đạt được năm 2017. EPS đạt 6.216 đồng/cổ phiếu.
#
# Với kết quả đạt được Viettel Post đã thông qua phương án phân phối lợi nhuận, trong đó ngoài phát hành cổ phiếu trả cổ tức tỷ lệ 41,4%, công ty còn cho hơn 62 tỷ đồng trả cổ tức bằng tiền tỷ lệ 15%. Tổng tỷ lệ trả cổ tức năm 2018 lên đến 56,4%.
#
# CTCP Vận tải và xếp dỡ Hải An (HAH) chi trả cổ tức năm 2018 bằng tiền tỷ lệ 15%. Thời gian thanh toán 24/6/2019.
#
# CTCP XNK Hàng Không (ARM) chi trả cổ tức năm 2018 bằng tiền tỷ lệ 20%. Thời gian thanh toán 25/6/2019.
#
# CTCP Viettronics Tân Bình (VTB) chi trả cổ tức năm 2018 bằng tiền tỷ lệ 15% Thời gian thanh toán 20/6/2019.
#
# CTCP Thiết bị điện (THI) chi trả cổ tức còn lại năm 2018 bằng tiền tỷ lệ 10%. Thời gian thanh toán 17/6/2019.
#
# CTCP Thương mại Hóc Môn (HTC) chi trả cổ tức đợt cuối năm 2018 bằng tiền tỷ lệ 3%. Thời gian thanh toán 21/6/2019.
#
# Ngày 5/6/2019: VNM, PNJ, VIB, SCS, NCT, HDC, SPD, TSB, POB,
#
# Ngày 5/6 là ngày giao dịch không hưởng quyền để CTCP Sữa Việt Nam (VNM) chốt danh sách cổ đông trả cổ tức còn lại năm 2018 bằng tiền tỷ lệ 15%. Thời gian thanh toán 26/6/2019. Như vậy Vinamilk sẽ chi khoảng 2.600 tỷ đồng trả cổ tức đợt này cho cổ đông.
#
# Năm 2018 Vinamilk đạt 52.562 tỷ đồng doanh thu, tăng 3% so với cùng kỳ, trong khi lợi nhuận sau thuế đạt 10.26 tỷ đồng, giảm nhẹ so với số lãi 10.278 tỷ đồng đạt được năm 2017. Với kết quả đạt được, ĐHCĐ thường niên năm 2019 đã phê chuẩn tổng mức cổ tức năm 2018 là 45%, trong đó công ty đã tạm ứng trước 30% trong năm 2018 và 2019.
#
# Ngày 5/6 là ngày giao dịch không hưởng quyền để CTCP Vàng bạc đá quý Phú Nhuận (PNJ) chốt danh sách cổ đông phát hành hơn 55 triệu cổ phiếu thưởng cho cổ đông do thực hiện tăng vốn cổ phần từ nguồn vốn chủ sở hữu. Tỷ lệ phát hành 33,33%, tương ứng cổ đông sở hữu 100 cổ phiếu được nhận về 33,33 cổ phiếu mới.
#
# Dự kiến sau phát hành PNJ sẽ tăng vốn điều lệ lên trên 2.220 tỷ đồng.
#
# Năm 2018, doanh thu thuần PNJ đạt 14.571 tỷ đồng, tăng 32,8% so với năm 2017. Lợi nhuận sau thuế xấp xỉ đạt 960 tỷ đồng, tăng 32,4% so với cùng kỳ. Tính đến hết năm 2018 PNJ còn hơn 884 tỷ đồng lợi nhuận sau thuế chưa phân phối. Ngoài ra còn 925 tỷ đồng thặng dư vốn cổ phần và hơn 265 tỷ đồng trong quỹ đầu tư phát triển.
#
# Ngân hàng TMCP Quốc tế Việt Nam (VIB) chi trả cổ tức bằng tiền tỷ lệ 5,67%. Thời gian thanh toán 8/7/2019.
#
# CTCP Dịch vụ hàng hóa Sài Gòn (SCS) chi trả cổ tức còn lại năm 2018 bằng tiền tỷ lệ 37%. Thời gian thanh toán 17/6/2019.
#
# CTCP Dịch vụ hàng hóa Nội Bài (NCT) chi trả cổ tức còn lại năm 2018 bằng tiền tỷ lệ 50%. Thời gian thanh toán 28/6/2019.
#
# CTCP Phát triển Nhà Bà Rịa – Vũng Tàu (HDC) phát hành hơn 7,5 triệu cổ phiếu trả cổ tức năm 2018 tỷ lệ 15%, tương ứng cổ đông sở hữu 100 cổ phiếu được nhận về 15 cổ phiếu mới.
#
# CTCP XNK Thủy sản Miền Trung (SPD) chi trả cổ tức năm 2018 bằng tiền tỷ lệ 5%. Thời gian thanh toán 20/6/2019.
#
# CTCP Ắc quy Tia Sáng (TSB) chi trả cổ tức năm 2018 bằng tiền tỷ lệ 2%. Thời gian thanh toán 19/6/2019.
#
# CTCP Xăng dầu dầu khí Thái Bình (POB) chi trả cổ tức năm 2018 bằng tiền tỷ lệ 1,8%. Thời gian thanh toán 19/6/2019.
#
# Ngày 6/6/2019: CTF, EVE, NDC, A32,
#
# CTCP City Auto (CTF) phát hành 3,96 triệu cổ phiếu trả cổ tức năm 2018 tỷ lệ 10%. Đồng thời công ty cũng phát hành gần 2 triệu cổ phiếu thưởng do thực hiện tăng vốn cổ phần từ nguồn vốn chủ sở hữu tỷ lệ 5%.
#
# CTCP Everpia (EVE) chốt danh sách cổ đông thực hiện chi trả cổ tức năm 2018 bằng tiền tỷ lệ 10%. Thời gian thanh toán 19/6/2019.
#
# CTCP Nam Dược (NDC) chi trả cổ tức năm 2018 bằng tiền tỷ lệ 20%. Thời gian thanh toán 25/6/2019.
#
# CTCP 32 (A32) chi trả cổ tức đợt 2/2018 bằng tiền tỷ lệ 7%. Thời gian thanh toán 20/6/2019.
#
# Ngày 7/6/2019: WCS, MDG, SHI, DVN, HGM, MEF, TV4, HTN, L14, HAS, LKW, BPC, PMS, TTG, HNB
#
# Ngày 7/6 là ngày giao dịch không hưởng quyền để CTCP Bến xe Miền Tây (WCS) chốt danh sách cổ đông thực hiện chi tạm ứng cổ tức đợt 1/2018 bằng tiền tỷ lệ 200%, tương ứng cổ đông sở hữu 1 cổ phiếu được nhận về 20.000 đồng. Thời gian thanh toán 26/6/2019.
#
# Năm 2018 cũng chỉ vượt nhẹ so với dự kiến với doanh thu đạt trên 153 tỷ đồng, vượt 5,25% kế hoạch và lợi nhuận sau thuế đạt gần 66,5 tỷ đồng, vượt 6,8% kế hoạch đặt ra cho cả năm. EPS thuộc TOP đầu thị trường với gần 22.000 đồng/cổ phiếu.
#
# Với kết quả đạt được, ĐHCĐ thường niên năm 2019 vừa qua đã thông qua tờ trình phân phối lợi nhuận, trong đó dành 100 tỷ đồng chia cổ tức cho năm 2018, tổng tỷ lệ 400%, tương ứng cổ đông sở hữu 1 cổ phiếu sẽ được nhận về 40.000 đồng.
#
# CTCP Bến xe Miền Đông (MDG) chi trả cổ tức con lại năm 2018 tỷ lệ 1% và tạm ứng cổ tức đợt 1/2019 tỷ lệ 3%. Tổng tỷ lệ chi trả 4%. Thời gian thanh toán 15/7/2019.
#
# CTCP Quốc tế Sơn Hà (SHI) dự kiến phát hành hơn 1,7 triệu cổ phiếu thưởng do thực hiện tăng vốn cổ phần từ nguồn vốn chủ sở hữu tức tỷ lệ 2% cho cổ đông. Giá trị phát hành theo mệnh giá 17 tỷ đồng. Nguồn vốn phát hành lấy từ LNST chưa phân phối.
#
# Tổng công ty Dược Việt Nam (DVN) chi trả cổ tức năm 2018 bằng tiền tỷ lệ 3%. Thời gian thanh toán 17/6/2019.
#
# CTCP Cơ khí và Khoáng sản Hà Giang (HGM) chi trả cổ tức đợt 2/2018 bằng tiền tỷ lệ 55%. Thời gian thanh toán 19/6/2019.
#
# CTCP Meinfa (MEF) chi trả cổ tức năm 2018 bằng tiền tỷ lệ 35%. Thời gian thanh toán 25/6/2019.
#
# CTCP Tư vấn xây dựng điện 4 (TV4) chi trả cổ tức đợt 2/201 bằng tiền tỷ lệ 5%. Thời gian thanh toán 25/6/2019.
#
# CTCP Hưng Thịnh Incons (HTN) chi trả cổ tức năm 2018 bằng tiền tỷ lệ 15%. Thời gian thanh toán 24/6/2019.
#
# CTCP Licogi 14 (L14) phát hành gần 1,5 triệu cổ phiếu trả cổ tức tỷ lệ 10%. Nguồn vốn phát hành lấy từ LNST chưa phân phối của công ty.
#
# CTCP Hasico (HAS) chi trả cổ tức năm 2018 bằng tiền tỷ lệ 6%. Thời gian thanh toán 20/6/2019.
#
# CTCP Cấp nước Long Khánh (LKW) chi trả cổ tức năm 2018 bằng tiền tỷ ệ 15%. Thời gian thanh toán 28/6/2019.
#
# CTCP Vicem Bao bì Bỉm Sơn (BPC) chi trả cổ tức năm 2018 bằng tiền tỷ lệ 10%. Thời gian thanh toán 15/7/2019.
#
# CTCP Cơ khí Dăng dầu (PMS) chi trả cổ tức năm 2018 bằng tiền tỷ lệ 15%. Thời gian thanh toán 24/6/2019.
#
# CTCP May Thanh Trì (TTG) chi trả cổ tức năm 2018 bằng tiền tỷ lệ 2%. Thời gian thanh toán 20/8/2019.
#
# CTCP Bến xe Hà Nội (HNB) chi trả cổ tức năm 2018 bằng tiền tỷ lệ 8%. Thời gian thanh toán 21/6/2019.
#
# Phạm Hải
#
# Theo Trí Thức Trẻ
# 3 Tập đoàn Xăng dầu Việt Nam (PLX): Ngày 31/5 – ngày ĐKCC nhận cổ tức năm 2018 bằng tiền tỷ lệ 27% (01 cổ phiếu nhận 2.700 đồng). Thời gian thanh toán 23/7/2019.
#
# CTCP Dịch vụ hàng hóa Sài Gòn (SCS): Ngày 6/6 – ngày ĐKCC nhận cổ tức còn lại năm 2018 bằng tiền tỷ lệ 37% (01 cổ phiếu nhận 3.700 đồng). Thời gian thanh toán 17/6/2019.
#
# CTCP Vinafreight (VNF): Ngày 14/6 – ngày ĐKCC nhận cổ tức năm 2018 bằng tiền tỷ lệ 10%. Thời gian thanh toán 15/7/2019.
#
# CTCP Cơ khí và Khoáng sản Hà Giang (HGM): Ngày 7/6 – ngày ĐKCC nhận cổ tức đợt 2/2018 bằng tiền tỷ lệ 55% (01 cổ phiếu nhận 5.500 đồng). Thời gian thanh toán 19/6/2019.
#
# CTCP Thiết bị điện (THI): Ngày 5/6 – ngày ĐKCC nhận cổ tức còn lại năm 2018 bằng tiền tỷ lệ 10% (01 cổ phiếu nhận 1.000 đồng). Thời gian thanh toán 17/6/2019.
#
# CTCP May Thanh Trì (TTG): Ngày 10/6 – ngày ĐKCC nhận cổ tức năm 2018 bằng tiền tỷ lệ 2% (01 cổ phiếu nhận 200 đồng). Thời gian thanh toán 20/8/2019.
#
# CTCP 32 (A32): Ngày 7/6 – ngày ĐKCC nhận cổ tức đợt 2/2018 bằng tiền tỷ lệ 7% (01 cổ phiếu nhận 700 đồng). Thời gian thanh toán 20/6/2019.
#
# CTCP Hưng Thịnh Incons (HTN): Ngày 10/6 – ngày ĐKCC nhận cổ tức năm 2018 bằng tiền tỷ lệ 15% (01 cổ phiếu nhận 1.500 đồng). Thời gian thanh toán 24/6/2019.
#
# Nguyên Phương
#
# Theo Trí Thức Trẻ
# 4 THÔNG TIN CÔNG TY Thứ 3, 28/05/2019, 13:27 CafeF.vn > Dữ liệu A32 Công ty cổ phần 32 (UpCOM) Giá hiện tại: A32 23.5 0(0) Hồ sơ công ty GDCĐ lớn & CĐ nội bộ
#
# Đơn vị KL: 10,000 CP Đơn vị giá: 1,000 VND
#
# Biểu đồ GTGD và KLGD trong 1 tháng Thông tin tài chính A32: 6.6.2019, ngày GDKHQ trả cổ tức bằng tiền mặt (700đ/cp) Ngày đăng ký cuối cùng trả cổ tức bằng tiền mặt Thông báo ngày đăng ký cuối cùng lập danh sách cổ đông đối với cổ phiếu A32 của CTCP 32 như sau:
#
# 1. Ngày đăng ký cuối cùng: 07/06/2019
#
# 2. Ngày giao dịch không hưởng quyền: 06/06/2019
#
# 3. Lý do và mục đích:
#
# * Trả cổ tức bằng tiền mặt - Tỷ lệ thực hiện: 7%/cổ phiếu (01 cổ phiếu được nhận 700 đồng)
#
# - Thời gian thực hiện: 20/06/2019
#
# - Địa điểm thực hiện:
#
# + Chứng khoán chưa lưu ký: Người sở hữu làm thủ tục nhận cổ tức tại Phòng TCKT - Công ty cổ phần 32; Địa chỉ: 170 Quang Trung, phường 10, quận Gò Vấp, Tp.HCM bắt đầu từ ngày 20/06/2019 và xuất trình chứng minh nhân dân.
#
# + Chứng khoán lưu ký: Người sở hữu làm thủ tục nhận cổ tức tại các Thành viên lưu ký nơi mở tài khoản lưu ký.
#
# Upcom:
# 5 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 6 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 7 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 8 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 9 THÔNG TIN CÔNG TY Thứ 6, 05/04/2019, 14:29 CafeF.vn > Dữ liệu A32 Công ty cổ phần 32 (UpCOM) Giá hiện tại: A32 23.5 0(0) Hồ sơ công ty GDCĐ lớn & CĐ nội bộ
#
# Đơn vị KL: 10,000 CP Đơn vị giá: 1,000 VND
#
# Biểu đồ GTGD và KLGD trong 1 tháng Thông tin tài chính A32: 16.4.2019, ngày GDKHQ Tham dự Đại hội đồng cổ đông thường niên năm 2019 Ngày đăng ký cuối cùng Tham dự Đại hội đồng cổ đông thường niên năm 2019 Thông báo ngày đăng ký cuối cùng lập danh sách cổ đông đối với cổ phiếu A32 của CTCP 32 như sau:
#
# 1. Ngày đăng ký cuối cùng: 17/04/2019
#
# 2. Ngày giao dịch không hưởng quyền: 16/04/2019
#
# 3. Lý do và mục đích:
#
# * Tham dự Đại hội đồng cổ đông thường niên năm 2019
#
# - Tỷ lệ phân bổ quyền: 01 cổ phiếu - 01 quyền biểu quyết
#
# - Thời gian họp: thông báo sau
#
# - Địa điểm tổ chức họp: Công ty cổ phần 32 - Số 170 Quang Trung, phường 10, quận Gò Vấp, Thành phố Hồ Chí Minh.
#
# - Nội dung họp: Họp Đại hội đồng cổ đông thường niên năm 2019
#
# Upcom:
# 10 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 11 Tuần mới từ 7/1 đến 11/1/2019 có 19 doanh nghiệp công bố chốt danh sách cổ đông thực hiện chi trả cổ tức bằng tiền, bằng cổ phiếu và chia cổ phiếu thưởng. Trong số đó thông tin nổi bật nhất là CTCP Vận tải bến bãi Sài Gòn chi tạm ứng cổ tức bằng tiền tỷ lệ 40%.
#
# Ngày 7/1/2019: SPM
#
# CTCP S.P.M (SPM) tạm ứng cổ tức năm 2018 bằng tiền tỷ lệ 10%. Thời gian thanh toán 13/1/2019.
#
# Ngày 8/1/2019: DHP, TTD, A32, DXV
#
#
#
# CTCP Điện cơ Hải Phòng (DHP) chi tạm ứng cổ tức đợt 1/2018 bằng tiền tỷ lệ 5%. Thời gian thanh toán 18/1/2019.
#
# CTCP Bệnh viên tim Tâm Đức (TTD) trả cổ tức đợt 2/2018 bằng tiền tỷ lệ 11%. Thời gian thanh toán 21/1/2019.
#
# CTCP 32 (A32) tạm ứng cổ tức năm 2018 bằng tiền tỷ lệ 15%. Thời gian thanh toán 21/1/2019.
#
# CTCP Vicem VLXD Đà Nẵng (DXV) trả cổ tức năm 2017 bằng tiền tỷ lệ 3%. Thời gian thanh toán 21/1/2019.
#
# Ngày 9/1/2019: DRL, BSH, HMH, NDP, BST, ICG
#
#
#
# CTCP Thủy điện – điện lực 3 (DRL) chi tạm ứng cổ tức đợt 3/2018 bằng tiền tỷ lệ 20%. Thời gian thanh toán 21/1/2019.
#
# CTCP Bia Sài Gòn Hà Nội (BSH) tạm ứng cổ tức đợt 2/2018 bằng tiền tỷ lệ 10%. Thời gian thanh toán 25/1/2019.
#
# CTCP Hải Minh (HMH) tạm ứng cổ tức đợt 2/2018 bằng tiền tỷ lệ 8%. Thời gian thanh toán 25/1/2019.
#
# CTCP Dược phẩm 2/9 (NDP) tạm ứng cổ tức đợt 2/2018 bằng tiền tỷ lệ 8%. Thời gian thanh toán 20/2/2019.
#
# CTCP Sách và thiết bị Bình Thuận (BST) tạm ứng cổ tức năm 2018 bằng tiền tỷ lệ 10%. Thời gian thanh toán 25/1/2019.
#
# CTCP Xây dựng Sông Hồng (ICG) trả cổ tức năm 2015 bằng tiền tỷ lệ 6%. Thời gian thanh toán 17/1/2019.
#
# Ngày 10/1/2019: TIP, POT, SD5
#
#
#
# CTCP Phát triển KCN Tín Nghĩa (TIP) tạm ứng cổ tức đợt 1/2018 bằng tiền tỷ lệ 15%. Thời gian thanh toán 24/1/2019.
#
# CTCP Thiết bị bưu điện (POT) tạm ứng cổ tức năm 2018 bằng tiền tỷ lệ 5%. Thời gian thanh toán 7/3/2019.
#
# CTCP Sông Đà 5 (SD5) trả cổ tức năm 2017 bằng tiền tỷ lệ 10%. Số tiền được chi trả làm 2 đợt, đợt 1 vào 31/1/2019 trả 5% và đợt 2 vào 29/3/2019 trả 5% còn lại.
#
# Ngày 11/1/2019: NAV, HNP, TV4, TPS, VIW, BTU
#
#
#
# CTCP Nam Việt (NAV) chi tạm ứng cổ tức năm 2018 bằng tiền tỷ lệ 6%. Thời gian thanh toán 31/1/2019.
#
# CTCP Hanel Xốp Nhựa (HNP) chi tạm ứng cổ tức năm 2018 bằng tiền tỷ lệ 17%. Thời gian thanh toán 28/1/2019.
#
# CTCP Tư vấn xây dựng điện 4 (TV4) tạm tạm ứng cổ tức năm 2018 bằng tiền tỷ lệ 5%. Thời gian thanh toán 30/1/2019.
#
# CTCP Vận tải bến bãi Sài Gòn (TPS) chi tạm ứng cổ tức năm 2018 bằng tiền tỷ lệ 40%. Thời gian thanh toán 25/1/2019.
#
# CTCP Nước và Môi trường Việt Nam (VIW) tạm ứng cổ tức năm 2018 bằng tiền tỷ lệ 7%. Thời gian thanh toán 25/1/2019.
#
# CTCP Công trình đô thị Bến Tre (BTU) tạm ứng cổ tức năm 2018 bằng tiền tỷ lệ 7%. Thời gian thanh toán 25/1/2019.
#
# Hóng tin "hot" tuần tới
#
# Tuần tới rất nhiều doanh nghiệp được nhà đầu tư quan tâm sẽ chốt danh sách cổ đông trả cổ tức bằng tiền, bằng cổ phiếu và chia cổ phiếu thưởng như Chứng khoán Sài Gòn Hà Nội, như FPT Online, hay như cao su Bình Long trả cổ tức tỷ lệ 66%...
#
# Nhà đầu tư muốn nhận số cổ tức/cổ phiếu thưởng này cần chú ý mua cổ phiếu trước ngày "lăn chốt".
#
# Phạm Hải
#
# Theo Trí Thức Trẻ
# 12 CTCP Hải Minh (HMH): Ngày 10/1 – ngày ĐKCC nhận tạm ứng cổ tức đợt 2/2018 bằng tiền tỷ lệ 8% (01 cổ phiếu nhận 800 đồng). Thời gian thanh toán 25/1/2019.
#
# CTCP Chăn nuôi Phú Sơn (PSL): Ngày 4/1 – ngày ĐKCC nhận tạm ứng cổ tức năm 2018 bằng tiền tỷ lệ 50% (01 cổ phiếu nhận 5.0000 đồng). Thời gian thanh toán 18/1/2019.
#
# CTCP Phát triển KCN Tín Nghĩa (TIP): Ngày 11/1 – ngày ĐKCC nhận cổ tức đợt 1/2018 bằng tiền tỷ lệ 15% (01 cổ phiếu nhận 1.500 đồng). Thời gian thanh toán 24/1/2019.
#
# CTCP Thiết bị phụ tùng Sài Gòn (SMA): Ngày 7/1 – ngày ĐKCC nhận cổ tức năm 2018 bằng tiền tỷ lệ 3% (01 cổ phiếu nhận 300 đồng). Thời gian thanh toán 23/1/2019.
#
# CTCP Địa ốc Chợ Lớn (RCL): Ngày 4/1 – ngày ĐKCC tạm ứng cổ tức đợt 2/2017 bằng tiền tỷ lệ 7% (01 cổ phiếu nhận 700 đồng). Thời gian thanh toán 17/1/2019.
#
# CTCP Cảng Đà Nẵng (CDN): Ngày 28/12 – ngày ĐKCC nhận tạm ứng cổ tức đợt 2/2018 bằng tiền tỷ lệ 2% (01 cổ phiếu nhận 200 đồng). Thời gian thanh toán 25/1/2019.
#
# CTCP Xây dựng bảo tàng Hồ Chí Minh (HMS): Ngày 2/1 – ngày ĐKCC nhận tạm ứng cổ tức đợt 1/2018 bằng tiền tỷ lệ 10% (01 cổ phiếu nhận 1.000 đồng). Thời gian thanh toán 17/1/2019.
#
# CTCP Hanel Xốp Nhựa (HNP): Ngày 14/1 – ngày ĐKCC nhận tạm ứng cổ tức năm 2018 bằng tiền tỷ lệ 17% (01 cổ phiếu nhận 1.700 đồng). Thời gian thanh toán 28/1/2019.
#
# CTCP Sivico (SIV): Ngày 2/1 – ngày ĐKCC nhận cổ tức năm 2018 bằng tiền tỷ lệ 15% (01 cổ phiếu nhận 1.500 đồng). Thời gian thanh toán 25/1/2019.
#
# CTCP 32 (A32): Ngày 9/1 – ngày ĐKCC nhận cổ tức năm 2018 bằng tiền tỷ lệ 15% (01 cổ phiếu nhận 1.500 đồng). Thời gian thanh toán 21/1/2019.
#
# CTCP S.P.M (SPM): Ngày 8/1/2019 – ngày ĐKCC nhận tạm ứng cổ tức năm 2018 bằng tiền tỷ lệ 10% (01 cổ phiếu nhận 1.000 đồng). Thời gian thanh toán 13/1/2019.
#
# CTCP May Đồng Nai (MDN): Ngày 7/1/2019 – ngày ĐKCC nhận tạm ứng cổ tức năm 2018 bằng tiền tỷ lệ 12% (01 cổ phiếu nhận 1.200 đồng). Thời gian thanh toán 21/1/2019.
#
# CTCP Sách và thiết bị Bình Thuận (BST): Ngày 10/1/2019 – ngày ĐKCC nhận cổ tức năm 2018 bằng tiền tỷ lệ 10% (01 cổ phiếu nhận 1.000 đồng). Thời gian thanh toán 25/1/2019.
#
# CTCP Nước và Môi trường Việt Nam (VIW): Ngày 14/1/2019 – ngày ĐKCC tạm ứng cổ tức năm 2018 bằng tiền tỷ lệ 7% (01 cổ phiếu nhận 700 đồng). Thời gian thanh toán 25/1/2019.
#
# CTCP Dệt may 29/3 (HCB – Đại chúng chưa niêm yết): Ngày 3/1 – ngày ĐKCC nhận cổ tức đợt 1/2018 bằng tiền tỷ lệ 10% (01 cổ phiếu nhận 1.000 đồng). Thời gian thanh toán 10/1/2019.
#
# Nguyên Phương
#
# Theo Trí Thức Trẻ
# 13 THÔNG TIN CÔNG TY Thứ 4, 26/12/2018, 15:18 CafeF.vn > Dữ liệu A32 Công ty cổ phần 32 (UpCOM) Giá hiện tại: A32 23.5 0(0) Hồ sơ công ty GDCĐ lớn & CĐ nội bộ
#
# Đơn vị KL: 10,000 CP Đơn vị giá: 1,000 VND
#
# Biểu đồ GTGD và KLGD trong 1 tháng Thông tin tài chính A32: 8.1.2019, ngày GDKHQ trả cổ tức bằng tiền mặt (1.500đ/cp) Ngày đăng ký cuối cùng trả cổ tức bằng tiền mặt Thông báo ngày đăng ký cuối cùng lập danh sách cổ đông đối với cổ phiếu A32 của CTCP 32 như sau:
#
# 1. Ngày đăng ký cuối cùng: 09/01/2019
#
# 2. Ngày giao dịch không hưởng quyền: 08/01/2019
#
# 3. Lý do và mục đích:
#
# * Trả cổ tức bằng tiền mặt - Tỷ lệ thực hiện: 15%/cổ phiếu (01 cổ phiếu được nhận 1.500 đồng)
#
# - Thời gian thực hiện: 21/01/2019
#
# - Địa điểm thực hiện:
#
# + Chứng khoán chưa lưu ký: Người sở hữu làm thủ tục nhận cổ tức tại Phòng TCKT - Công ty cổ phần 32; Địa chỉ: 170 Quang Trung, phường 10, quận Gò Vấp, Tp.HCM bắt đầu từ ngày 21/01/2019 và xuất trình chứng minh nhân dân.
#
# + Chứng khoán lưu ký: Người sở hữu làm thủ tục nhận cổ tức tại các Thành viên lưu ký nơi mở tài khoản lưu ký.
#
# HNX:
# 14 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 15 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 16 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 17 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 18 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 19 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 20 Công ty Cổ phần Nhựa An Phát Xanh (mã CK: AAA) đã công bố BCTC quý 1/2019 với con số lãi tăng trưởng vượt trội so với cùng kỳ.
#
# Theo đó, doanh thu thuần trong kỳ đạt 2.612 tỷ đồng tăng cao gấp hơn 2 lần so với cùng kỳ, sau khi trừ đi giá vốn AAA lãi gộp gần 375 tỷ đồng tăng 153% so với cùng kỳ 2018.
#
# Trong kỳ AAA thu về gần 53 tỷ đồng doanh thu từ hoạt động tài chính cao gấp 7,6 lần cùng kỳ tuy nhiên chi phí của hoạt động này cũng tăng mạnh từ 25,6 tỷ đồng lên gần 63 tỷ đồng do tăng chi phí lãi vay.
#
# Sau khi trừ các khoản chi phí và ghi nhận thêm 7,2 tỷ đồng lợi nhuận từ hoạt động khác, AAA đạt 214 tỷ đồng LNST công ty mẹ tăng mạnh so với con số hơn 49 tỷ đồng trong quý 1/2018.
#
# Theo giải trình từ phía công ty lợi nhuận tăng mạnh là do trong kỳ công ty TNHH Khu công nghiệp kỹ thuật cao An Phát đã phát sinh doanh thu chuyển nhượng quyền thuê đất và nhà xưởng trong khu công nghiệp An Phát Complex và góp phần vào lợi nhuận hợp nhất 169 tỷ đồng.
#
# Năm 2019, AAA đề ra tổng doanh thu đạt 10.000 tỷ đồng, tăng 25% so năm 2018. Đáng chú ý, AAA đặt kế hoạch lãi ròng đạt đến 510 tỷ đồng, gấp 2,8 lần so năm trước trong đó lĩnh vực sản xuất đóng góp 210 tỷ đồng, thương mại 70 tỷ đồng, khai thác hạ tầng KCN 220 tỷ đồng và hoạt động khác là 10 tỷ đồng. Như vậy với kết quả đạt được thì ngay trong quý 1 thì AAA đã hoàn thành được 26% mục tiêu về doanh thu và đã hoàn thành được tới 42% kế hoạch lợi nhuận.
#
# Sang quý 2/2019, AAA đặt kế hoạch lợi nhuận trước thuế 200 tỷ đồng. ANECO sẽ tiếp tục tích cực làm việc với các hãng bay như Vietnam Airlines, Bamboo hay Vietjet để đưa các sản phẩm nhựa thân thiện với môi trường vào hệ thống các hãng bay này. Bên cạnh đó An Phát Complex đang nhận được sự quan tâm của các doanh nghiệp ngành điện tử từ Đài Loan, Nhật Bản,…được kỳ vọng tiếp tục đem lại lợi nhuận khả quan trong năm 2019.
#
# AAA cho biết với kết quả kinh doanh quý 1/2019 khả quan và diễn biến tích cực từ thị trường, HĐQT công ty đang xem xét điều chỉnh tăng kế hoạch kinh doanh năm 2019.
#
# AAA đang được sở hữu 46,62% bởi Tập đoàn An Phát (công ty mẹ) và sắp tới, trong ĐHCĐ, AAA sẽ trình phương án để An Phát nắm giữ 51%. Tỉ lệ thuận với sự tăng trưởng của AAA, Tập đoàn An Phát trong thời gian gần đây có nhiều bứt phá, sản phẩm nhựa của công ty đã gia nhập chuỗi cung ứng của Samsung và An Trung Industries, một công ty thành viên khác của Tập đoàn chính thức trở thành nhà cung cấp cấp 2 của Samsung. Ban lãnh đạo Toyota Việt Nam và An Phát cũng đang bắt tay hợp tác trong vấn đề nội địa hóa. Cuối năm 2018, An Phát cũng có hợp tác với Vinfast.
#
# Kết quả kinh doanh tích cực đã phản ánh vào giá cổ phiếu AAA trên sàn chứng khoán. Chốt phiên giao dịch ngày 26/4, AAA tăng 3,4% lên 18.500 đồng/cổ phiếu. Thanh khoản AAA cũng rất ấn tượng, khối lượng khớp lệnh bình quân 10 phiên gần nhất lên tới gần 4,9 triệu đơn vị. Theo đó giá của cổ phiếu AAA đã tăng gần 30% so với mức giá 14.500 đồng/cổ phiếu ngày đầu năm 2019. Vốn hóa của AAA hiện tăng lên 3.000 tỷ đồng.
#
# Tú Anh
#
# Theo Infonet/HSX
# 21 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 22 Lãi quý 1/2019 tăng trưởng tới cả 5 con số
#
# Theo BCTC quý 1/2019 đã được các doanh nghiệp niêm yết trên hai sàn công bố thì đây hiện là những doanh nghiệp đang có mức lãi tăng trưởng rất ấn tượng ngay trong quý kinh doanh đầu tiên của năm 2019. Đáng chú ý kết quả lãi của những doanh nghiệp này hầu hết đều đến từ hoạt động kinh doanh chính.
#
# Trong khi Vietcombank (VCB) đạt mức tăng trưởng 34%, MBB tăng 25% hay TCB chỉ tăng 1,6%, SAB tăng 9,6%...thì Sacombank (STB) đã công bố con số lãi 844 tỷ đồng trong quý 1/2019 đạt mức tăng trưởng lên tới gần 113%. Với kết quả này ngay quý 1 STB đã hoàn thành được 40% mục tiêu lợi nhuận cả năm 2019.
#
# Các doanh nghiệp thuỷ sản cũng đã có kết quả kinh doanh quý 1 rất khả quan khi đồng loạt công bố mức lãi lớn, trong đó Vĩnh Hoàn lãi ròng 307 tỷ đồng gấp 3 lần cùng kỳ năm trước nhờ xuất khẩu cá tra tăng mạnh về giá. Cũng nhờ lượng xuất khẩu và giá bán tăng trưởng tốt đã giúp ANV lãi ròng hơn 200 tỷ đồng tăng 164% so với cùng kỳ.
#
# Đáng chú ý là khoản lãi 54 tỷ đồng của Thuỷ sản Cửu Long An Giang (ACL) – con số này cao gấp 9 lần cùng kỳ, tuy nhiên kế hoạch kinh doanh năm 2019 của ACL đang chỉ là lãi trước thuế 180 tỷ đồng giảm 31% so với thực hiện 2018. Tiếp đó là Camimex Group (CMX) cũng báo lãi cao gấp 6 lần cùng kỳ đạt hơn 24 tỷ đồng tuy nhiên trong đó có một phần đóng góp lớn của khoản lãi khác từ thanh lý và nhượng bán tài sản cố định.
#
# Cặp đôi AMV và SRA mặc dù doanh thu và lợi nhuận đã giảm nhiệt so với 2 quý trước đó tuy nhiên vẫn góp mặt trong danh sách này bởi khoản lãi tăng mạnh so với cùng kỳ. Hiện, AMV và SRA có chung người tư vấn chiến lược, mỗi đơn vị làm tại những mảng riêng, cùng với một số doanh nghiệp khác mục tiêu hình thành hệ thống chuyên cung cấp trang thiết bị, dịch vụ y tế.
#
# Một số doanh nghiệp BĐS cũng đã có lợi nhuận bứt phá trong quý 1 trong đó phải kể đến Nam Long (NLG), nhờ Mua Việt Thiên Lâm đã giúp quý đầu năm của NLG có lợi nhuận đột biến lên 145 tỷ đồng tăng 358% so với cùng kỳ. Tiếp đó nhờ hoạt động chuyển nhượng BĐS, hoạt động hợp tác đầu tư và môi giới đã giúp đầu tư LDG (LDG) lãi ròng 121 tỷ đồng cao gấp 25 lần cùng kỳ.
#
# Lideco (NTL) cũng công bố trong quý 1/2019 lãi ròng hơn 36 tỷ đồng tăng 264% so với cùng kỳ năm ngoái nhờ ghi nhận doanh thu tăng mạnh. Lideco dự kiến sẽ đẩy mạnh đầu tư bất động sản Hạ Long, do đó đặt mục tiêu tăng trưởng lợi nhuận hơn 130% trong năm 2019 đạt 295 tỷ đồng.
#
# Trong khi các doanh nghiệp cùng ngành như TMT, HAX đều công bố mức lãi thấp trong quý 1 thì City Auto (CTF) lại cáo lãi quý 1 đạt 25 tỷ đồng cao gấp 10 lần cùng kỳ do trong kỳ lượng xe bán ra tăng mạnh trong đó đáng kể là dòng xe Ranger, do từ tháng 4.2019 dòng xe này tăng lệ phí trước bạ từ 2% lên 6%.
#
# Với kế hoạch lãi 510 tỷ đồng gấp 2,8 lần so với 2018, An Phát Plastic (AAA) đang hiện thực hoá kế hoạch tham vọng của mình khi báo lãi ngay quý 1 đạt 214 tỷ đồng tăng 335% so với cùng kỳ 2018. Dự án đáng kể nhất của Công ty là Khu công nghiệp An Phát Complex đang thu nhận những kết quả khả quan. Bên cạnh đó trong tháng 2/2019, An Phát Plastic được dư luận trong và ngoài nước quan tâm khi được chọn là một trong 3 doanh nghiệp toàn quốc được phái đoàn ngoại giao của lãnh đạo Triều Tiên Kim Jong Un đến thăm quan nhà máy. Nhờ đó, hình ảnh của AAA trở nên gần gũi hơn với bạn bè quốc tế.
#
# Vinasun (VNS) đã thoát khỏi những ngày khốn khó nhất khi tiếp tục báo lãi quý thứ 3 liên tiếp, lợi nhuận sau thuế Công ty quý đầu năm 2019 đạt 32 tỷ đồng, tăng gần 3 lần so với mức 11,6 tỷ hồi quý 1/2018. Năm 2019, Vinasun (VNS) sẽ chú trọng nâng cấp ứng dụng gọi xe, đầu tư thêm tối thiểu 320 xe mới, công ty đặt mục tiêu lợi nhuận sau thuế năm 2019 tăng gần 12% lên 99,6 tỷ đồng.
#
# Dự kiến lãi cao trong năm 2019
#
# Nếu soi kế hoạch kinh doanh năm 2019 của những doanh nghiệp này thì có thể thấy đa phần đều dự tính con số lãi tăng trưởng mạnh so với 2018, trong đó đáng chú ý là kế hoạch của BAX, với mục tiêu lãi cao gần gấp 3 lần, Lideco và AAA cũng đặt mục tiêu lãi lớn trong năm 2019.
#
# Triển vọng kinh doanh 2019 không chỉ được các doanh nghiệp này sớm công bố mà kèm theo đó là những thông tin để hoàn thành được mục tiêu, theo đó LDG hé lộ đang đàm phán một dự án tại Đà Nẵng dự kiến sẽ mang về doanh thu "khủng" cho doanh nghiệp trong nhiều năm. Lideco dự kiến sẽ đẩy mạnh đầu tư bất động sản Hạ Long, Vinasun (VNS) cho biết sẽ chú trọng nâng cấp ứng dụng gọi xe, đầu tư thêm tối thiểu 320 xe mới trong năm 2019...
#
# AAA cũng tiết bộ nhà máy của công ty đang tập trung nguồn lực và vật lực cho đơn tăng của tháng 4 và tháng 5. Toàn bộ các dây chuyền đang chạy tối đa công suất để đáp ứng đơn của khách tại gần 100 quốc gia và khu vực thế giới. Không chỉ có kết quả tích cực từ hoạt động xuất khẩu túi mà AAA cũng đã hoàn thiện mọi thủ tục pháp lý để chính thức sở hữu toàn bộ An Phát Complex. Đây cũng chính là tiền đề thuận lợi để AAA có thể kinh doanh mảng "bất động sản công nghiệp.
#
# Thanh Tú
#
# Theo Infonet/HNX&HSX
# 23 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 24 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 25 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 26 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 27 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 28 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 29 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 30 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 31 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 32 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 33 Biểu đồ GTGD và KLGD trong 1 tháng
#
# AAA: Giải trình chênh lệch lợi nhuận BCTC HN và Cty mẹ năm 2018 so với cùng kỳ năm trước Công ty Cổ phần Nhựa và Môi trường Xanh An Phát giải trình chênh lệch lợi nhuận BCTC HN và Cty mẹ năm 2018 so với cùng kỳ năm trước như sau: Các tập tin đính kèm 20190318_20190318 - AAA - Giai trinh chenh lech loi nhuan. BCTC hop nhat nam 2018 kiem toan.pdf 20190318_20190318 - AAA - Giai trinh chenh lech loi nhuan. BCTC rieng nam 2018 kiem toan.pdf HSX
# 34 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 35 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 36 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 37 Biểu đồ GTGD và KLGD trong 1 tháng
#
# AAA: Giải trình chênh lệch lợi nhuận BCTC HN và Cty mẹ quý 4 năm 2018 so với cùng kỳ năm trước Công ty Cổ phần Nhựa và Môi trường Xanh An Phát giải trình chênh lệch lợi nhuận BCTC HN và Cty mẹ quý 4 năm 2018 so với cùng kỳ năm trước như sau: Các tập tin đính kèm 20190130_20190130 - AAA - Giai trinh chenh lech loi nhuan BCTC cong ty me Quy 4 2018.PDF 20190130_20190130 - AAA - Giai trinh chenh lech loi nhuan BCTC hop nhat Quy 4 2018.PDF
#
#
#
# HSX
# 38 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 39 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 40 Biểu đồ GTGD và KLGD trong 1 tháng
#
# AAA: Quyết định của Cục thuế Tỉnh Hải Dương v/v xử phạt vi phạm hành chính về thuế năm 2017 Công ty Cổ phần Nhựa và Môi trường Xanh An Phát công bố Quyết định của Cục thuế Tỉnh Hải Dương về việc xử phạt vi phạm hành chính về thuế năm 2017 và giải trình như sau: Các tập tin đính kèm 20181227_20181227 - AAA - CBTT và giai trinh vv cham CBTT quyet dinh xu phat thue.pdf
#
#
#
# HSX
# 41 CTCP Nhựa và Môi trường An Phát (AAA) là doanh nghiệp số một Đông Nam Á về sản xuất bao bì nhựa màng mỏng với tổng công suất 8.000 tấn sản phẩm/tháng. Không chỉ xuất khẩu sang Nhật Bản, châu Âu, mới đây AAA đã cung cấp sản phẩm túi vi sinh phân hủy hoàn toàn mang tên AnEco cho các siêu thị thuộc hệ thống Vinmart.
#
# Với ngành nghề kinh doanh giàu tiềm năng tăng trưởng, kết quả kinh doanh AAA đã duy trì sự bứt phá mạnh mẽ trong nhiều năm qua. Mới đây, ông Nguyễn Lê Trung – Tổng giám đốc AAA đã có những chia sẻ với chúng tôi về kết quả kinh doanh năm 2018 cũng như kế hoạch triển khai kinh doanh năm tiếp theo.
#
# Thời điểm cuối năm, nhiều nhà đầu tư băn khoăn về kế hoạch kinh doanh năm 2018 của AAA. Ông có thể cung cấp con số cụ thể được không?
#
# Ông Nguyễn Lê Trung: Năm 2018, chúng tôi đặt kế hoạch mức doanh thu là 6.000 tỷ đồng và lợi nhuận sau thuế là 330 tỷ đồng. Nhưng thực tế, cho đến thời điểm này, doanh thu của AAA đã vượt kế hoạch đề ra, đạt 7.000 tỷ đồng, đây là kết quả chủ yếu của việc mở rộng mảng hoạt động thương mại hạt nhựa và tăng sản lượng bao bì do 2 nhà máy số 06 và số 07 của AAA đi vào hoạt động.
#
# Tuy vậy, lợi nhuận sau thuế của chúng tôi lại dự báo khó đạt kế hoạch, dự kiến là 200 tỷ đồng do một số hợp đồng thực hiện chậm, phải hoãn sang năm 2019 và nguyên nhân thứ 2 là do AAA đặt tiêu chí "sự hài lòng của khách hàng" lên hàng đầu cũng như tăng cường tìm kiếm thêm các thị trường mới nên trong năm qua, mặc dù giá nguyên liệu đầu vào tăng nhưng chúng tôi không tăng giá bán sản phẩm nhiều.
#
# Như vậy có thể nói rằng kế hoạch kinh doanh của AAA không đạt mục tiêu đề ra?
#
# Ông Nguyễn Lê Trung: Khi kinh doanh hay đầu tư vào một dự án nào đó, chúng ta nên nhìn về tương lai lâu dài. Có những thời điểm sẽ có khó khăn, trở ngại nhưng quan trọng nhất là bạn đã có cơ sở vật chất, thị trường ổn định, đội ngũ nhân lực mạnh… thì chắc chắn đó chỉ là vấn đề tạm thời.
#
# Mặt khác, tôi nghĩ rằng không chỉ với riêng AAA mà các doanh nghiệp khác, kể cả doanh nghiệp nước ngoài khi đầu tư vào một lĩnh vực nào mới thì họ cũng sẽ đề ra kế hoạch dài hơi trong vòng 3 năm, 5 năm hoặc 10 năm và sẽ xác định doanh thu, lợi nhuận cho từng năm mà thường thì trong thời gian đầu họ sẽ chấp nhận…bù tiền để khi có thị trường và thương hiệu ổn định rồi sẽ bắt đầu có lãi trong các năm tiếp theo.
#
# Trở lại với trường hợp của AAA, năm nay lợi nhuận của chúng tôi giảm là do hợp đồng thực hiện chậm nhưng hợp đồng này sẽ tiếp tục được chạy trong năm sau chứ không phải là dừng nên lợi nhuận của năm 2019 sẽ tăng hơn. Đồng thời với việc nhà máy số 6 và số 7 chạy tối đa công suất sẽ đem lại hiệu quả hoạt động cao hơn do tận dụng được quy mô sản xuất lớn, giá bán cũng sẽ được chúng tôi cân đối dần dần, đảm bảo biên độ lợi nhuận tốt nhất của mảng bao bì.
#
# Ngoài ra, một số hợp tác được kí kết cuối năm với các đối tác trong ngành nhựa và các hoạt động tăng cường R&D của Công ty cũng sẽ giúp chi phí nguyên liệu đầu vào của AAA được tối ưu hóa, là động lực cho tăng trưởng lợi nhuận và hiệu quả hoạt động của doanh nghiệp.
#
# Ông vừa nhắc đến kế hoạch và tương lai lâu dài, vậy phải chăng AAA đang đầu tư vào nhiều dự án?
#
# Ông Nguyễn Lê Trung: Đúng như vậy, năm vừa qua, chúng tôi đã mua lại Khu Công nghiệp Việt Hòa- Kenmark rộng 46ha với giá gần 800 tỷ đồng. Vì đây là dự án chết lâm sàng, đã bị bỏ hoang hơn 10 năm nên không có ngân hàng nào cho chúng tôi vay vốn đầu tư vào đây nên AAA phải tự lo toàn bộ.
#
# Sau khi mua, chúng tôi đã đổi tên là An Phát Complex. Với sự đầu tư mạnh mẽ về công nghệ, máy móc, nhân lực và vật lực, An Phát Complex đã thay da đổi thịt hàng ngày và nơi đây đang là cứ điểm sản xuất của các Công ty An Trung, An Vinh, An Cường với các sản phẩm mang hàm lượng công nghệ cao…Trong tương lai gần, An Phát Complex sẽ là khu công nghệ cao đích thực với nhiều doanh nghiệp khác ngoài hệ thống Tập đoàn APH (công ty mẹ của AAA) do chúng tôi đã và đang triển khai mảng cho thuê đất và cơ sở vật chất.
#
# Hiện nay, chúng tôi đã đạt được một số thỏa thuận với đối tác nước ngoài và chắc chắn trong năm tới, An Phát Complex sẽ đem lại lợi nhuận tốt. Hiện tại, An Phát Complex đang có 450 nhân sự và dự kiến trong thời gian tới sẽ tăng lên 1.000 người.
#
# Bên cạnh đó, các công ty cùng hệ thống của AAA trong KCN An Phát Complex như An Trung, An Vinh… đang có đà tăng trưởng và tiềm năng rất tốt. Chúng tôi đang trong giai đoạn hoàn thiện cơ sở vật chất và nhân lực để có thể trở thành nhà cung ứng cho một số tập đoàn nước ngoài lớn.
#
# Ông đặt kế hoạch kinh doanh như thế nào cho AAA trong năm tới đây?
#
# Ông Nguyễn Lê Trung: Tôi hoàn toàn tự tin để khẳng định rằng hiện nay AAA đang đi đúng hướng và chúng tôi đang sử dụng nguồn đầu tư đúng mục đích. Những dự án dài hơi cần có sự đầu tư và thời gian nhất định thì mới có kết quả tốt và trong tương lai gần, lợi nhuận của AAA sẽ tăng trưởng mạnh trở lại. Năm tới, chúng tôi đặt mục tiêu cho kế hoạch doanh thu hợp nhất của AAA là 7.900 tỷ đồng và lợi nhuận sau thuế là 510 tỷ đồng.
#
# PV
#
# Theo Trí Thức Trẻ
# 42 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 43 Ngày 28/11/2018, Sở Kế hoạch Đầu tư Thành phố Hải Phòng đã cấp giấy chứng nhận đăng ký kinh doanh cho một doanh nghiệp mới có tên: "Công ty TNHH Linh kiện Nhựa Ô tô Vinfast-An Phát".
#
# Doanh nghiệp này có trụ sở chính tại Nhà máy đúc nhựa thuộc Tổ hợp sản xuất ô tô VinFast tại khu kinh tế Đình Vũ - Cát Hải với ngành nghề kinh doanh chính là sản xuất phụ tùng ô tô. Theo nguồn tin riêng đáng tin cậy thì Tổng giám đốc của VinFast-An Phát là ông Mẫn Chí Trung, một cái tên được báo chí nhắc đến nhiều trong thời gian qua với thương vụ An Phát Holdings (APH) mua lại Nhựa Hà Nội. Hiện tại, ông Trung đang nắm giữ chức vụ Phó Giám đốc Công ty An Trung, đơn vị thành viên của APH và mới được bầu tham gia HĐQT của CTCP Nhựa Hà Nội (NHH).
#
# Thông tin đáng chú ý khác là tại Đại hội đồng cổ đông bất thường tổ chức ngày 25/11 của Nhựa Hà Nội đã thông qua phương án chấp thuận cho An Phát Holdings nhận chuyển nhượng đến 50% tổng số cổ phần của Nhựa Hà Nội mà không phải thực hiện chào mua công khai.
#
# Với việc cả 2 cổ đông lớn nhất là Cadivi Đồng Nai và MB Capital cùng đăng ký bán ra thì có thể thấy việc An Phát Holdings nắm quyền kiểm soát Nhựa Hà Nội chỉ là vấn đề hoàn tất một số thủ tục.
#
# Nhựa Hà Nội hiện là một là công ty chuyên sản xuất các sản phẩm nhựa thuộc ngành công nghiệp phụ trợ như phụ tùng ô tô, xe máy và cung cấp cho Toyota Việt Nam, Honda Việt Nam, Piaggio Việt Nam, VMEP…Nhựa Hà Nội cũng đã ký một số hợp đồng cung cấp phụ tùng xe máy cho VinFast. Như vậy, căn cứ vào thương vụ mua lại Nhựa Hà Nội của APH thì hoàn toàn có cơ sở để khẳng định Tập đoàn này đang "bắt tay" với Vinfast. Nếu động thái này là thật thì chứng tỏ APH đang có tham vọng rất lớn trong việc trở thành một trong những nhà sản xuất linh kiện nhựa hàng đầu phục vụ cho lĩnh vực công nghiệp ô tô-xe máy.
#
# Hiện nay, An Phát Holdings hay Vinfast chưa công bố bất kỳ thông tin nào về liên doanh mới thành lập này. Trước đây, khi mua lại Nhựa Hà Nội, An Phát Holdings cũng khá kín tiếng.
#
# Bên cạnh mảng kinh doanh truyền thống là bao bì mảng mỏng, An Phát Holdings mở rộng sang 6 lĩnh vực kinh doanh chính là: nhựa sinh học, nhựa bao bì, nhựa gia dụng, nhựa kỹ thuật, hóa dầu và xơ sợi với 12 nhà máy và trên 2.500 lao động. An Phát Holdings hiện nay có 11 Công ty thành viên, nổi bật nhất trong số đó là Công ty CP Nhựa và Môi trường Xanh An Phát (An Phát Plastic - AAA).
#
#
#
# Minh Nguyệt
#
# Theo Trí Thức Trẻ
# 44 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 45 Ngày 22/11, Công ty TNHH MTV Cadivi Đồng Nai bất ngờ ra thông báo bán đi toàn bộ 3.370.700 cổ phiếu NHH tương ứng 51,86% vốn điều lệ của CTCP Nhựa Hà Nội. Giao dịch dự kiến thực hiện từ 23/11 đến 21/12/2018 theo phương thức thỏa thuận và khớp lệnh.
#
#
#
# Động thái này diễn ra ngay trước Đại hội đồng cổ đông bất thường của Nhựa Hà Nội sẽ được tổ chức vào ngày 25/11 tới đây với nội dung chính là miễn nhiệm và bầu bổ sung thành viên HĐQT và Ban kiểm soát công ty.
#
# Một thông tin đáng chú ý khác là ngày 12/11 mới đây, Tập đoàn An Phát Holdings (APH) - công ty mẹ của CTCP Nhựa và môi trường xanh An Phát (AAA) bất ngờ ký biên bản ghi nhớ (MoU) về việc hợp tác với Gelex, công ty mẹ của Cadivi Đồng Nai. Biên bản ghi nhớ (MoU) đã đánh dấu sự hợp tác về cung cấp nguyên liệu, bán thành phẩm, chia sẻ các kênh phân phối, chia sẻ thực hiện các cơ hội đầu tư tiềm năng, đẩy mạnh cùng phát triển các sản phẩm thân thiện với môi trường và ngành công nghiệp phụ trợ của Việt Nam giữa APH và GELEX.
#
# Những động thái này dẫn đến việc nhiều nhà đầu tư nghĩ đến khả năng An Phát Holdings cùng các công ty thành viên có thể là ứng viên sáng giá sẽ mua lại Nhựa Hà Nội.
#
# Nhựa Hà Nội hiện là một trong những công ty hàng sản xuất các sản phẩm nhựa thuộc ngành công nghiệp phụ trợ như Phụ tùng Ô tô, xe máy cấp cho Toyota Việt Nam, Honda Việt Nam, Piaggio Việt Nam, VMEP; linh kiện điện, điện tử, xây dựng cấp cho Panasonic, KORG Việt Nam cung cấp các hộp nhựa, pallet công nghiệp cho các ngành sản xuất công nghiệp trong nước; Chế tạo khuôn mẫu cho ngành nhựa... Nhựa Hà Nội cũng đã ký một số hợp đồng cung cấp phụ tùng xe máy cho VinFast.
#
# Đây là lĩnh vực kinh doanh đầy tiềm năng và sẽ giúp gia tăng chuỗi giá trị các sản phẩm ngành nhựa mà An Phát Holdings xây dựng nếu như doanh nghiệp này mua lại được Nhựa Hà Nội. Theo một nguồn tin đáng tin cậy thì ông Bùi Minh Hải, nguyên Phó Tổng Giám đốc của AAA, hiện là Giám đốc Ban Kế hoạch và Tái cấu trúc của APH cùng ông Mẫn Chí Trung, Phó Giám đốc An Trung (đơn vị thành viên của APH) là2 ứng viên sẽ tham gia ứng cử vào HĐQT của Nhựa Hà Nội tại đại hội tới đây.
#
#
#
#
#
# Trường An
#
# Theo Trí Thức Trẻ
# 46 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 47 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 48 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 49 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 50 CTCP Tập đoàn An Phát Holdings vừa thông báo đã hoàn tất mua vào 10 triệu cổ phiếu AAA của CTCP Nhựa và Môi trường xanh An Phát đăng ký mua trước đó, nâng lượng sở hữu tại Anphat Plastics từ hơn 65,31 triệu cổ phiếu (tỷ lệ 38,15%) lên 75,31 triệu cổ phiếu (tỷ lệ 43,99%). Giao dịch thực hiện theo phương thức thỏa thuận và khớp lệnh từ 17/10 đến 31/10/2018.
#
#
#
# Ngay sau khi mua xong lượng cổ phiếu đăng ký, An Phát Holdings lại đăng ký mua tiếp 7 triệu cổ phiếu AAA với mục đích đầu tư nắm giữ cổ phiếu lâu dài. Giao dịch dự kiến thực hiện từ 6/11 đến 5/12/2018 theo phương thức thỏa thuận và khớp lệnh.
#
# Nếu giao dịch thành công An Phát Holdings sẽ nâng lượng sở hữu tại Anphat Plastics lên 82,31 triệu cổ phiếu tương ứng 48,08% tổng số cổ phiếu có quyền biểu quyết đang lưu hành của công ty.
#
# Về mối quan hệ, An Phát Holdings là công ty do ông Phạm Ánh Dương, Chủ tịch HĐQT của Anphat Plastics làm Chủ tịch, ngoài ra ông Phạm Hoàng Việt, ông Nguyễn Lê Trung, Thành viên HĐQT của AAA cũng là Thành viên HĐQT An Phát Holdings, ông Đinh Xuân Cường, Thành viên HĐQT của AAA là Thành viên HĐQT kiêm Tổng Giám đốc của An Phát Holdings.
#
# Trong khi An Phát Holdings liên tục gom hàng thì cổ đông ngoại Pyn Elite Fund lại đang nhanh chóng thoái vốn. Chỉ trong những ngày tháng 10, Pyn Elite đã nhiều lần bán ra tổng cộng hơn 3 triệu cổ phiếu AAA.
#
# Còn trước đó trong tháng 8/2018 chính ông Nguyễn Lê Trung và ông Nguyễn Hoàng Việt cũng bán đi lượng lớn cổ phiếu AAA.
#
# Trên thị trường cổ phiếu AAA đang đà giảm sâu, về mức đáy trong vòng 2 năm trở lại đây. Nếu tính riêng từ đầu tháng 10 đến nay AAA đã mất đi 19% giá trị, giảm từ vùng giá 17.500 đồng/cổ phiếu xuống 14.250 đồng/cổ phiếu như hiện nay. Còn nếu tính từ đầu năm 2018 đến nay AAA đã giảm đến 42%.
#
# ...
#
# Diễn biến giá cổ phiếu AAA trong 6 tháng gần đây.
#
# Ngoài ra CTCP Thương mại XNK Thiên Nam (mã chứng khoán TNA) cũng thông qua việc phát hành 512.009 cổ phiếu ESOP cho người lao động trong công ty. Đối tượng phát hành là các cán bộ chủ chốt được nhận thấy có khả năng đóng góp cho công ty, có thành tích nổi bật và hiệu quả làm việc cao, luôn hoàn thành xuất sắc nhiệm vụ…
#
# Nguồn vốn thực hiện lấy từ thặng dư vốn cổ phần theo BCTC kiểm toán năm 2017. Số cổ phiếu ESOP này bị hạn chế chuyển nhượng trong vòng 1 năm kể từ ngày kết thúc đợt phát hành.
#
# Diễn biến giá cổ phiếu TNA trong 6 tháng gần đây.
#
# Thái Phương
#
# Theo Trí Thức Trẻ
# 74 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 75 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 76 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 77 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 78 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 79 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 80 CTCP Nhựa và Môi trường xanh An Phát (Anphat Plastic – mã chứng khoán AAA) vừa thông báo đã hoàn tất mua thêm 4,6 triệu cổ phiếu HII của CTCP Nhựa và Khoáng sản An Phát – Yên Bái. Giao dịch thực hiện theo phương thức thỏa thuận từ 1/8 đến 24/8/2018.
#
# Sau giao dịch Anphat Plastic nâng lượng sở hữu cổ phiếu HII từ 9,6 triệu đơn vị (tỷ lệ 34,47%) lên 14,2 triệu đơn vị tương ứng 50,99% tổng số cổ phiếu có quyền biểu quyết đang lưu hành của Khoáng sản An Phát Yên Bái.
#
# Trước giao dịch này, mặc dù tỷ lệ sở hữu dưới 50% nhưng An Phát Yên Bái vẫn được ghi nhận là công ty con của Nhựa An Phát do có 3/5 Thành viên HĐQT của HII là Thành viên Ban giám đốc của AAA và là đại diện quản lý vốn của công ty tại HII nên Anphat Plastic đã nắm quyền kiểm soát tại HII.
#
# Khoáng sản An Phát Yên Bái là doanh nghiệp thành lập từ tháng 10/2009 với ngành nghề kinh doanh chính là sản xuất, kinh doanh hạt nhựa và hạt phụ gia tạo thành bởi phụ gia và bột đá… Chủ tịch HĐQT của Khoáng sản An Phát Yên Bái là ông Vũ Thanh Bình, sinh năm 1988.
#
# Kết quả kinh doanh, năm 2017 HII đạt 1.331 tỷ đồng doanh thu thuần, tăng đột biến gấp 6,8 lần doanh thu đạt được năm 2016, còn lợi nhuận sau thuế đạt 61,5 tỷ đồng, gấp 5,3 lần cùng kỳ.
#
# Năm 2017 được xem là một trong những dấu mốc quan trọng của HII khi công ty hoàn thành xây dựng và đưa vào sản xuất dự án Nhà máy bột đá siêu mịn CaCO3, góp phần chủ động nguồn nguyên liệu bột đá CaCO3 siêu mịn cho nhà máy sản xuất hạt nhựa.
#
# Trần Thành
#
# Theo Trí Thức Trẻ
# 81 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 82 CTCP An Phát Holdings vừa thông báo đã hoàn tất mua vào hơn 9 triệu cổ phiếu AAA của CTCP Nhựa và Môi trường xanh An Phát đã đăng ký mua trước đó. Giao dịch thành công Anphat Holdings nâng lượng sở hữu cổ phiếu AAA từ hơn 53,29 triệu cổ phiếu (tỷ lệ 31,9%) lên hơn 62,32 triệu cổ phiếu, tương ứng 37,3% tổng số cổ phiếu đang lưu hành của Nhựa An Phát.
#
#
#
# An Phát Holdings là công ty do ông Phạm Anh Dương, Chủ tịch HĐQT của Nhựa An Phát, làm Chủ tịch. Bên cạnh đó ông Phạm Hoàng Việt, ông Nguyễn Lê Trung, ông Đinh Xuân Cường, Thành viên HĐQT của AAA cũng là Thành viên HĐQT của An Phát Holdings. Ông Đinh Xuân Cường cũng kiêm luôn vị trí Tổng Giám đốc của An Phát Holdings.
#
# Số cổ phiếu An Phát Holdings vừa mua vào là số cổ phiếu từ 2 lãnh đạo chủ chốt của AAA là Chủ tịch Phạm Anh Dương (5,6 triệu cổ phiếu) và Tổng Giám đốc Nguyễn Lê Trung (3,4 triệu cổ phiếu).
#
# Sau khi An Phát Holdings hoàn tất mua vào hơn 9 triệu cổ phiếu AAA, ông Phạm Hoàng Việt, Thành viên HĐQT Nhựa An Phát cũng đăng ký bán hết toàn bộ gần 3 triệu cổ phiếu AAA đang sở hữu theo phương thức thỏa thuận. Giao dịch dự kiến thực hiện từ 28/8 đến 26/9/2018.
#
# Mai Nguyễn
#
# Theo Infonet
# 83 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 84 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 85 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 86 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 87 Biểu đồ GTGD và KLGD trong 1 tháng
#
# AAA: Giải trình lợi nhuận sau thuế 6 tháng đầu năm 2018 so với cùng kỳ năm trước Công ty Cổ phần Nhựa và Môi trường Xanh An Phát công bố giải trình lợi nhuận sau thuế 6 tháng đầu năm 2018 so với cùng kỳ năm trước như sau: Các tập tin đính kèm 20180815_20180815 - AAA - Giai trinh chenh lech loi nhuan sau thue cong ty me.pdf 20180815_20180815 - AAA - Giai trinh chenh lech loi nhuan sau thue hop nhat.pdf
#
#
#
# HSX
# 88 Thực hiện mục tiêu nâng quyền kiểm soát tại CTCP Nhựa và Môi trường xanh An Phát (AAA), CTCP An Phát Holdings vừa ra thông báo đăng ký mua 9.025.990 cổ phiếu từ cổ đông sáng lập trong thời gian từ 3/8 đến 01/9/2018.
#
#
#
# Hiện An Phát Holdings đang sở hữu 32% cổ phần của AAA, dự kiến sau khi mua vào, tỷ lệ sở hữu của An Phát Holdings tại AAA sẽ nâng lên 38%.
#
# Số cổ phiếu trên dự kiến được An Phát Holdings mua lại từ 2 lãnh đạo chủ chốt của AAA là Chủ tịch hội đồng quản trị Phạm Ánh Dương (5,6 triệu cổ phiếu) và Tổng giám đốc Nguyễn Lê Trung (3,4 triệu cổ phiếu).
#
# Nhựa An Phát cho biết việc ban lãnh đạo công ty tiếp tục chuyển nhượng cổ phần sang An Phát Holdings càng khẳng định chắc chắn cam kết nắm giữ cổ phiếu lâu dài của cổ đông sáng lập khi chuyên nghiệp hóa việc sở hữu lên mức độ tổ chức.
#
# Việc tập trung tăng sở hữu về An Phát Holdings sẽ đẩy mạnh hoạt động tái cấu trúc theo quy mô tập đoàn, tập trung nguồn lực tập đoàn và các công ty thành viên tại An Phát Plastic để phát triển các ngành sản xuất mới xung quanh cốt lõi ngành nhựa.
#
# Bên cạnh mảng bao bì, An Phát sẽ mở rộng phát triển thêm 5 lĩnh vực mới bao gồm: nhựa sinh học, nhựa gia dụng, nhựa kỹ thuật, hóa dầu và xơ sợi, hướng tới hoàn thiện chuỗi giá trị kinh doanh khép kín ngành nhựa, phát triển các sản phẩm công nghệ cao, thân thiện với môi trường - động lực cho tăng trưởng bền vững của doanh nghiệp.
#
# Song song với đó, chuyển đổi hình thức sở hữu sang quy mô tổ chức sẽ hỗ trợ minh bạch hoá cấu trúc sở hữu và chuyên nghiệp hoá việc quản lý sản xuất kinh doanh của ban lãnh đạo AAA. Khi tập trung sở hữu và các hoạt động nghiên cứu, đầu tư phát triển các ngành nghề kinh doanh mới tại An Phát Holdings, An Phát sẽ có nhiều thuận lợi để phát triển tối đa hóa hệ sinh thái thịnh vượng, đẩy nhanh tốc độ tăng trưởng và hạn chế tối đa sự ảnh hưởng từ biến động của thị trường.
#
# Để hiện thực hóa chiến lược phát triển bền vững này, trong năm 2018, An Phát Holdings sẽ tiếp tục đăng kí mua cổ phiếu AAA, thực hiện mục tiêu nâng tỷ lệ sở hữu lên 51%, tăng quyền kiểm soát tại AAA như đã được thông qua trong ĐHĐCĐ thường niên 2018.
#
# Bên cạnh An Phát Holdings, Pyn Elite Fund - một trong những quỹ đầu tư lớn nhất trên thị trường chứng khoán Việt Nam – cũng liên tục gia tăng sở hữu tại AAA trong thời gian gần đây. Quỹ này bắt đầu trở thành cổ đông lớn nắm giữ trên 5% vào ngày 4/4/2018 và đến nay đã tăng tỷ lệ nắm giữ lên 8,46%, tương ứng với gần 14,2 triệu cổ phiếu.
#
# Trường An
#
# Theo Trí Thức Trẻ
# 89 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 90 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 91 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 92 Biểu đồ GTGD và KLGD trong 1 tháng
#
# AAA: Giải trình chênh lệch LNST BCTC HN và Cty mẹ quý 2.2018 so với cùng kỳ năm trước Công ty Cổ phần Nhựa và Môi trường Xanh An Phát giải trình chênh lệch LNST BCTC HN và Cty mẹ quý 2.2018 so với cùng kỳ năm trước như sau: Các tập tin đính kèm 20180730_20180730 - AAA - Giai trinh bao cao tai chinh hop nhat quy II.2018.PDF 20180730_20180730 - AAA - Giai trinh bao cao tai chinh cong ty me quy II.2018.PDF
#
#
#
# HSX
# 93 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 94 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 95 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 96 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 97 Sáng ngày 15/06, CTCP Nhựa và Môi trường Xanh An Phát (AAA: Hose) đã tổ chức buổi Hội nghị tiếp xúc nhà đầu tư tại cụm công nghiệp An Đồng, Nam Sách, Hải Dương. Đến tham dự hội nghị có hàng chục nhà đầu tư, nhà phân tích của các công ty chứng khoán và đại diện của các quỹ đầu tư trong, ngoài nước. Về phía công ty, ông Phạm Ánh Dương- Chủ tịch HĐQT cùng với ông Nguyễn Lê Trung- Tổng Giám đốc đã có mặt để trao đổi cũng như trả lời những thắc mắc của nhà đầu tư.
#
#
#
# Ông Phạm Ánh Dương- Chủ tịch HĐQT nhựa An Phát trình bày về kết quả hoạt động của công ty
#
# Tại buổi trò chuyện, ông Phạm Ánh Dương giới thiệu sơ lược về lịch sử 15 năm hình thành của An Phát và không giấu nổi niềm tự hào khi trong năm 2017 công ty đã vượt qua các đối thủ trong khu vực để trở thành nhà sản xuất bao bì màng mỏng lớn nhất Đông Nam Á với sản lượng 96.000 tấn/năm. Trong giai đoạn 2013-2017, tốc độ tăng trưởng bình quân của doanh thu và LNST hợp nhất lần lượt đạt 28,6% và 32,4%. Riêng trong năm 2017, doanh thu và LNST của An Phát tăng 90% so với năm 2016.
#
# Q1/2018, An Phát tiếp tục đạt được những kết quả khả quan khi sản lượng sản xuất của công ty đạt hơn 18 nghìn tấn, tăng 39% so với cùng kỳ năm trước. Doanh thu hợp nhất tăng gần 80% so với cùng kỳ, tuy nhiên LNST giảm nhẹ so với cùng kỳ (do Q1/2017 công ty ghi nhận lợi nhuận 35 tỷ đồng từ việc thoái vốn tại bao bì Vinh (VBC: HNX).
#
# Ông Dương cho biết, tầm nhìn của An Phát không chỉ dừng lại ở mức là nhà sản xuất bao bì thân thiện với môi trường hàng đầu khu vực mà còn hướng đến tạo dựng chuỗi giá trị công nghiệp và xây dựng, phát triển hệ sinh thái của ngành công nghiệp nhựa. An Phát muốn cùng các doanh nghiệp Việt Nam cùng phát triển, nâng tầm vị thế thương hiệu nhựa kỹ thuật cao và thân thiện với môi trường. Định hướng phát triển của hệ sinh thái của An Phát sẽ xoay quanh 6 mảng:
#
# Để thực hiện việc mở rộng hệ sinh thái, An Phát đã mua thành công lô đất có tổng diện tích 46ha khu công nghiệp (KCN) Việt Hòa-Kenmark theo hình thức mua đấu giá từ BIDV với giá 756 tỷ đồng. Công ty đang làm thủ tục để có thể đổi tên thành KCN tổ hợp nhựa kỹ thuật cao An Phát (An Phát Complex). Trong lô đất mới mua thì đã có sẵn 8 block đã xây dựng sẵn với tổng diện tích sử dụng là 12,8ha và hệ thống điện, xử lý nước đã có sẵn. Theo đánh giá của công ty thì riêng việc tiền vốn bỏ ra để xây mới diện tích nhà xưởng như vậy ở thời điểm hiện tại sẽ tốn đến 400-500 tỷ đồng chưa kể tiền đất.
#
# Ngoài 8 block nhà sẵn có, An Phát vẫn còn hơn 35ha để phát triển các dự án tùy theo nhu cầu phát triển của công ty trong tương lai. Một ưu điểm khác khi mua lại KCN này là An Phát sẽ được miễn thuế thu nhập doanh nghiệp (TNDN) trong vòng 4 năm đầu tiên và giảm 50% thuế TNDN trong 9 năm tiếp theo.
#
# Báo cáo về tình hình sử dụng vốn của doanh nghiệp về đợt phát hành tăng vốn mới đây, ban lãnh đạo cho biết An Phát đã thu về được 1.170 tỷ đồng, trong đó 360 tỷ sử dụng để đầu tư vào Anbio và 810 tỷ còn lại đầu tư vào 3 công ty con là An Vinh, Đại An và An Cường.
#
# Anbio là dự án trọng điểm của An Phát trong thời gian tới khi tập trung sản xuất bao bì tự hủy sinh học (với nguyên liệu là thành phần hữu cơ, có thể tan hoàn toàn trong đất trong vòng 1 năm). Sản phẩm của Anbio hoàn toàn thân thiện với môi trường và phù hợp với những thị trường quan tâm tới vấn đề này. Biên lãi gộp của Anbio sẽ ở mức 20% từ năm 2020 và dự kiến sẽ mang về mức doanh thu trên 5.000 tỷ đồng trong năm 2025.
#
# Bên cạnh Anbio, Đại An cũng là một bước đi đầy chiến lược của An Phát. Đại An sẽ tập trung sản xuất linh kiện nhựa ép phun kỹ thuật cao và mục tiêu của An Phát là trở thành vendor cấp 1 của những doanh nghiệp FDI hàng đầu Việt Nam. Ngoài việc được ưu đãi thuế trong 13 năm đầu như các dự án khác tại KCN, Đại An chỉ chịu mức thuế TNDN 10% trong những năm sau đó.
#
# Cổ đông có trăn trở về kỳ vọng của Đại An khi làm việc với những FDI hàng đầu, liệu rằng công ty có đủ kỹ thuật để làm hay không? Liệu có đảm bảo được rằng sản phẩm làm ra sẽ được họ sử dụng hay không? Và với quy mô lớn của họ, liệu Đại An có lo ngại bị ép giá?
#
# Giải đáp những thắc mắc này, ông Dương cho biết An Phát không "ngồi và tự nghĩ ra thị trường" mà họ đã có nhiều cuộc họp, làm việc nhiều lần với đối tác nước ngoài để lên kế hoạch về sự hợp tác lẫn nhau. Ngoài ra, về mặt chính sách, chính phủ Việt Nam yêu cầu các doanh nghiệp FDI cần nâng cao tỷ lệ nội địa hóa, nên nếu doanh nghiệp trong nước có thể cung ứng sản phẩm phù hợp với yêu cầu của các doanh nghiệp FDI thì chắc chắn họ sẽ sử dụng sản phẩm của chúng ta.
#
# Kết thúc Hội nghị, chủ tịch Phạm Ánh Dương thay mặt ban lãnh đạo gửi lời tri ân tới cổ đông, những người luôn đồng hành cùng doanh nghiệp trong thời điểm khó khăn và tin tưởng doanh nghiệp với những kế hoạch trong tương lai. Ban lãnh đạo của công ty tin rằng với tổ hợp sinh thái của An Phát, công ty sẽ có đạt mức doanh thu 1 tỷ USD trong năm 2025, góp phần nâng tầm doanh nghiệp ngành nhựa Việt Nam trên trường quốc tế.
#
# Mai Ngọc
#
# Theo Nhịp sống kinh tế
# 98 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
# 99 (*) Lưu ý: Dữ liệu được tổng hợp từ các nguồn đáng tin cậy, có giá trị tham khảo với các nhà đầu tư.
#
# Tuy nhiên, chúng tôi không chịu trách nhiệm trước mọi rủi ro nào do sử dụng các dữ liệu này.
#
# Theo Trí thức trẻ
